# %% [markdown]
# ## Scatter Plot

# %%
import seaborn as sns
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', data=tips)
plt.show()

# %% [markdown]
# ## Hue, Style and Size

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker', style='time')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, style='size')
plt.show()

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
sns.relplot(x='total_bill', y='tip', data=tips, style='smoker')
plt.show()

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill', y='tip', data=tips, size='size', sizes=(15, 200))
plt.show()

# %%
tips['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# ## Line Plot

# %%
from seaborn import relplot

# %% [markdown]
# from numpy.random import randn

# %%
df = pd.DataFrame(dict(time=np.arange(500), value=randn(500).cumsum()))

# %%
relplot(x='time', y='value', kind='line', data=df)

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
fig, ax = plt.subplots()
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri)

# %%
relplot(x='timepoint', y='signal', kind='line', data=fmri, ci=False, label='Signal', height=4, aspect=2)
plt.legend(loc='right')

# %%
fmri[fmri['timepoint'] == 5].mean()
# Out:
# C:\Users\Emanuel\AppData\Local\Temp\ipykernel_1152\351825320.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   fmri[fmri['timepoint'] == 5].mean()
# timepoint    5.000000
# signal       0.137725
# dtype: float64

# %%
fmri[fmri['timepoint'] == 5].min()
# Out:
# subject            s0
# timepoint           5
# event             cue
# region        frontal
# signal      -0.017946
# dtype: object

# %%
relplot(x='timepoint', y='signal', kind='line', hue='event', data=fmri, label='Signal', height=4, aspect=2)
plt.legend(loc='right')

# %%
relplot(x='timepoint', y='signal', kind='line', hue='event', style='region', data=fmri, label='Signal', height=4, aspect=2)
plt.legend(loc='right')

# %%
relplot(x='timepoint', y='signal', kind='line', style='event', markers=True, dashes=False, data=fmri, label='Signal', height=4, aspect=2)
plt.legend(loc='right')

# %%
dots = sns.load_dataset('dots').query("align=='dots'")

# %%
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 389  dots     T2   680        3.2    37.806267
# 390  dots     T2   700        0.0    43.464959
# 391  dots     T2   700        3.2    38.994559
# 392  dots     T2   720        0.0    41.987121
# 393  dots     T2   720        3.2    41.716057
#
# [394 rows x 5 columns]

# %%
relplot(x='time', y='firing_rate', data=dots, kind='line')

# %%
relplot(x='time', y='firing_rate', data=dots, kind='line', hue='coherence', style='choice')

# %%
pallette = sns.cubehelix_palette(light=0.9, n_colors=6)
relplot(x='time', y='firing_rate', data=dots, kind='line', hue='coherence', style='choice', palette=pallette)

# %%
relplot(x='time', y='firing_rate', data=dots, kind='line', hue='coherence', style='choice', size='choice')

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %% [markdown]
# ## Subplots

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
relplot(x='total_bill', y='tip', hue='smoker', col='time', data=tips)

# %%
relplot(x='total_bill', y='tip', hue='smoker', col='smoker', data=tips)

# %%
relplot(x='total_bill', y='tip', hue='smoker', col='size', data=tips)

# %%
relplot(x='total_bill', y='tip', hue='smoker', col='time', data=tips, row='size')

# %%
relplot(x='total_bill', y='tip', hue='smoker', col='size', data=tips, col_wrap=3)

# %% [markdown]
# ## Using sns.lineplot() and sns.scatterplot()

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x='timepoint', y='signal', style='event', hue='region', data=fmri, markers=True, ci=68, err_style='bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x='timepoint', y='signal', hue='event', data=fmri.query("region=='frontal'"), estimator=None, lw=1)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='smoker', size='size', style='time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Categorical Data Ploting

# %% [markdown]
# ### Cat Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day', y='total_bill', data=tips)

# %%
sns.catplot(x='total_bill', y='day', data=tips)

# %%
sns.catplot(x='day', y='total_bill', data=tips, jitter=False)

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='swarm')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='swarm', hue='size')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='smoker', y='tip', data=tips)

# %%
sns.catplot(x='smoker', y='tip', data=tips, order=['No', 'Yes'])

# %% [markdown]
# ### Box Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day', y='total_bill', kind='box', data=tips)

# %%
sns.catplot(x='day', y='total_bill', kind='box', data=tips, hue='sex')

# %%
sns.catplot(x='day', y='total_bill', kind='box', data=tips, hue='sex', dodge=False)

# %% [markdown]
# ### Boxen Plot

# %%
diamonds = sns.load_dataset('diamonds')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x='color', y='price', kind='boxen', data=diamonds)

# %%
sns.catplot(x='color', y='price', kind='boxen', data=diamonds, hue='cut')

# %%
sns.catplot(x='color', y='price', kind='boxen', data=diamonds, hue='cut', dodge=False)

# %% [markdown]
# ### Violin Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='total_bill', y='day', data=tips)

# %%
sns.catplot(x='total_bill', y='day', data=tips, kind='violin')

# %%
sns.catplot(x='total_bill', y='day', data=tips, kind='violin', hue='sex')

# %%
sns.catplot(x='total_bill', y='day', data=tips, kind='violin', hue='sex', split=True)

# %%
g = sns.catplot(x='day', y='total_bill', data=tips, kind='swarm')
sns.violinplot(x='day', y='total_bill', data=tips, kind='violin', hue='sex', split=True, ax=g.ax, height=3, color='k')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
g = sns.catplot(x='day', y='total_bill', data=tips, kind='swarm')
sns.violinplot(x='day', y='total_bill', data=tips, kind='violin', split=True, ax=g.ax, color='k')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Bar Plot

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='sex', y='survived', kind='bar', data=titanic)

# %%
sns.catplot(x='sex', y='survived', kind='bar', data=titanic, hue='class')

# %%
sns.catplot(x='sex', y='survived', kind='bar', data=titanic, hue='class', palette='ch:0.05')

# %% [markdown]
# ### Point Plot

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='sex', y='survived', hue='class', kind='point', data=titanic)

# %% [markdown]
# ### Joint Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = tips['total_bill']
y = tips['tip']

# %%
sns.jointplot(x, y)
# Out:
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(x, y, kind='hex')
# Out:
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(x, y, kind='kde')
# Out:
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Pair Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips)

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot)

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels=10)

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.swarmplot)
# Out:
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 88.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 87.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 70.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 82.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 75.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 69.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 73.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 41.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 70.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 75.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 31.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Emanuel\PycharmProjects\HelloWorld\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 24.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Regression Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x='total_bill', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x='size', y='tip', data=tips)

# %% [markdown]
# ## Controlling Ploted Figure Aesthetics

# %% [markdown]
# ### figure styling
# ### axes styling
# ### color palettes
# ### etc..

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i*0.5)*(7-i)*flip)

# %%
sinplot()

# %%
sinplot(-1)

# %%
sns.set_style('ticks', {'axes.grid':True, 'xticks.direction':'in'})
sinplot()
sns.despine(left=False, bottom=False)

# %%
sns.set_style('ticks', {'axes.grid':True, 'xticks.direction':'in'})
sinplot()
sns.despine()

# %%
sns.set_style('ticks', {'axes.grid':True, 'xticks.direction':'in'})
sinplot()

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style('darkgrid')

# %%
sns.set_style('dark')

# %%
sinplot()
